# %%
import numpy as np
import sklearn.neural_network

# %%
xs = np.array([
    0, 0,
    0, 1,
    1, 0,
    1, 1
]).reshape(4, 2)

ys = np.array([0, 1, 1, 0]).reshape(4,)

# %%
model = sklearn.neural_network.MLPClassifier(
    activation='logistic', max_iter=1000,
    learning_rate_init=0.1, hidden_layer_sizes=(3)
)
model.fit(xs, ys)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=3,
#               learning_rate_init=0.1, max_iter=1000)

# %%
print('score:', model.score(xs, ys))
print('predictions:', model.predict(xs))
print('expected:', np.array([0, 1, 1, 0]))
# Out:
# score: 1.0
# predictions: [0 1 1 0]
# expected: [0 1 1 0]
